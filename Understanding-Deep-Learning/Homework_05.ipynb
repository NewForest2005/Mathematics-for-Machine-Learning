# %% [markdown]
# # Understanding Deep Learning — Homework 5
#
# Use this notebook for the fifth homework from *Understanding Deep Learning* by Simon J. D. Prince.

# %% [markdown]
# ## Instructions
#
# - Add the homework statement or a link to it here.
# - Write explanations in Markdown and solutions in code cells.
# - Record any assumptions, sources, and results.
